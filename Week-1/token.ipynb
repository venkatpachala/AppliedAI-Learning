# %%
import tiktoken
encoding = tiktoken.encoding_for_model("gpt-4.1-mini")
tokens = encoding.encode("Hey this is venkat")

# %%
tokens
# Out:
# [25216, 495, 382, 9055, 14408]

# %%
for token_id in tokens:
    token_text=encoding.decode([token_id])
    print(f"{token_id} = {token_text}")
# Out:
# 25216 = Hey
# 495 =  this
# 382 =  is
# 9055 =  ven
# 14408 = kat

# %%
import requests

url = "http://localhost:11434/api/chat"

messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "Hey I am Venky"}

]

payload = {
    "model": "llama3",
    "messages": messages,
    "stream": False
}

# %%
response = requests.post(url, json=payload)
print(response.json()["message"]["content"])
# print(response.json())
# Out:
# Nice to meet you, Venky! How can I help you today? Do you have any questions or topics you'd like to discuss? I'm all ears!

# %%
messages=[
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "What is my name?"}

]

response=requests.post(url, json=payload)
print(print(response.json()["message"]["content"]))
# Out:
# Nice to meet you, Venky! How can I assist you today? Do you have any questions, need help with something, or just want to chat? I'm all ears!
# None

# %%
print(payload)
# Out:
# {'model': 'llama3', 'messages': [{'role': 'system', 'content': 'You are a helpful assistant'}, {'role': 'user', 'content': 'Hey I am Venky'}], 'stream': False}
